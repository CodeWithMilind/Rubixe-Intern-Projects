# %%
import pandas as pd

# pd.set_option()
df = pd.read_csv("./bank-additional/bank-additional-full.csv", sep=";")

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
#  i want to check does default column affect the target variable ( yes or no )

pd.crosstab(df['default'],df['y'])
# Out:
# y           no   yes
# default
# no       28391  4197
# unknown   8154   443
# yes          3     0

# %%
df = pd.read_csv("Encoded_EDA_DONE.csv")

# %%
from cwmeda import plot_columns

plot_columns(df,['age', 'education', 'housing',  'day_of_week'],n_cols=2,plot_type='box',theme='skyblue',target='y',main_title="Features vs Target")
