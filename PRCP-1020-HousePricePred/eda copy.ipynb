# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cwmeda as m

# %%
df = pd.read_csv("Data/data.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['Alley'].value_counts(dropna=False)
# Out:
# Alley
# NaN     1369
# Grvl      50
# Pave      41
# Name: count, dtype: int64

# %%
# compare nan with others and detect where will Grvl and pave
# predict Alley 
m.plot_columns(df,df.select_dtypes(include=['int64','float64']).columns.to_list(),plot_type="box",n_cols=3)
# Out:
# ⚠️ Too many columns! Showing first 12 only.
# c:\Users\milind\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\cwmeda\__init__.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, y=col, palette=palette, color=color)
# c:\Users\milind\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\cwmeda\__init__.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, y=col, palette=palette, color=color)
# c:\Users\milind\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\cwmeda\__init__.py:70: FutureWarning:
#
# ...

# %%
import vizion as vz

# %%
vz.data_summary(df)
# Out:
# DATA SUMMARY
# -----------
# Shape: (1460, 81)
# Numeric columns: 38
# Categorical columns: 43
# Datetime columns: 0
# Columns with missing values: 19
# Duplicated rows: 0
# Top missing columns (col, %):
#   - PoolQC: 99.52%
#   - MiscFeature: 96.30%
#   - Alley: 93.77%
#   - Fence: 80.75%
#   - MasVnrType: 59.73%
#   - FireplaceQu: 47.26%
#   - LotFrontage: 17.74%
#   - GarageType: 5.55%
#   - GarageYrBlt: 5.55%
#   - GarageFinish: 5.55%
# High cardinality categorical columns (sample):
#   - Neighborhood: 25
#   - Exterior2nd: 16
#   - Exterior1st: 15
#   - Condition1: 9
#   - SaleType: 9
#   - Condition2: 8
#   - HouseStyle: 8
#   - RoofMatl: 8
#   - BsmtFinType1: 7
#   - BsmtFinType2: 7
#
# Sample rows:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# ...

# %%
outliers = vz.detect_outliers(df)
outliers
# Out:
# {'Id': 0,
#  'MSSubClass': 103,
#  'LotFrontage': 88,
#  'LotArea': 69,
#  'OverallQual': 2,
#  'OverallCond': 125,
#  'YearBuilt': 7,
#  'YearRemodAdd': 0,
#  'MasVnrArea': 96,
#  'BsmtFinSF1': 7,
#  'BsmtFinSF2': 167,
#  'BsmtUnfSF': 29,
#  'TotalBsmtSF': 61,
#  '1stFlrSF': 20,
#  '2ndFlrSF': 2,
#  'LowQualFinSF': 26,
#  'GrLivArea': 31,
#  'BsmtFullBath': 1,
#  'BsmtHalfBath': 82,
#  'FullBath': 0,
#  'HalfBath': 0,
#  'BedroomAbvGr': 35,
#  'KitchenAbvGr': 68,
#  'TotRmsAbvGrd': 30,
#  'Fireplaces': 5,
#  'GarageYrBlt': 0,
#  'GarageCars': 5,
#  'GarageArea': 21,
#  'WoodDeckSF': 32,
#  'OpenPorchSF': 77,
#  'EnclosedPorch': 208,
#  '3SsnPorch': 24,
#  'ScreenPorch': 116,
#  'PoolArea': 7,
#  'MiscVal': 52,
#  'MoSold': 0,
#  'YrSold': 0,
#  'SalePrice': 61}

# %%
df_clean, report = vz.fix_missing(df, strategy='auto')
print(report)
# Out:
# {'LotFrontage': {'method': 'median', 'filled': 1}, 'Alley': {'method': 'mode'}, 'MasVnrType': {'method': 'mode'}, 'MasVnrArea': {'method': 'median', 'filled': 1}, 'BsmtQual': {'method': 'mode'}, 'BsmtCond': {'method': 'mode'}, 'BsmtExposure': {'method': 'mode'}, 'BsmtFinType1': {'method': 'mode'}, 'BsmtFinType2': {'method': 'mode'}, 'Electrical': {'method': 'mode'}, 'FireplaceQu': {'method': 'mode'}, 'GarageType': {'method': 'mode'}, 'GarageYrBlt': {'method': 'median', 'filled': 1}, 'GarageFinish': {'method': 'mode'}, 'GarageQual': {'method': 'mode'}, 'GarageCond': {'method': 'mode'}, 'PoolQC': {'method': 'mode'}, 'Fence': {'method': 'mode'}, 'MiscFeature': {'method': 'mode'}}

# %%
meta = vz.analyze_df(df)
models = vz.suggest_models(meta, target="SalePrice", df=df)
for m in models:
    print(m)
# Out:
# {'model': 'LinearRegression', 'reason': 'Simple baseline for regression; low variance if features are not many.'}
# {'model': 'RandomForestRegressor', 'reason': 'Robust to outliers and works with mixed features.'}
# {'model': 'XGBoost/LightGBM', 'reason': 'Powerful gradient boosters — good next step.'}

# %%
vz.detect_outliers(df, filename="report.html")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 vz.detect_outliers(df, filename="report.html")
#
# TypeError: detect_outliers() got an unexpected keyword argument 'filename'
